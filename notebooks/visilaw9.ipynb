# %%
from jose import jwt, JWTError

SECRET_KEY = "dev-secret-key-change-later"
ALGORITHM = "HS256"


def verify_and_decode_jwt(token: str) -> dict:
    """
    Verify JWT signature and return decoded claims.
    """
    try:
        payload = jwt.decode(
            token,
            SECRET_KEY,
            algorithms=[ALGORITHM],
            options={"verify_exp": False},  # Disable expiration verification for dev
        )
        return payload
    except JWTError:
        raise ValueError("Invalid or expired JWT")

# %%
pip install python-jose
# Out:
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# ...
#
#    ---------------------------------------- 0/4 [pyasn1]
#    ---------- ----------------------------- 1/4 [ecdsa]
#    ------------------------------ --------- 3/4 [python-jose]
#    ---------------------------------------- 4/4 [python-jose]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from jose import jwt, JWTError
print("JWT OK")
# Out:
# JWT OK

# %%
from jose import jwt
from datetime import datetime, timedelta

SECRET_KEY = "dev-secret-key-change-later"
ALGORITHM = "HS256"

def create_jwt(
    user_id: str,
    department: str,
    clearance: int,
    expires_minutes: int = 60
) -> str:
    payload = {
        "sub": user_id,
        "department": department,
        "clearance": clearance,
        "exp": datetime.utcnow() + timedelta(minutes=expires_minutes)
    }

    token = jwt.encode(payload, SECRET_KEY, algorithm=ALGORITHM)
    return token

# %%
token = create_jwt(
    user_id="u_test",
    department="engineering",
    clearance=2
)

token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1X3Rlc3QiLCJkZXBhcnRtZW50IjoiZW5naW5lZXJpbmciLCJjbGVhcmFuY2UiOjIsImV4cCI6MTc2OTYxNzE3NX0.7_UP9_mrLz8C6FRbmoEKztrKqaAmP2WfphvaJ8ZaHYM'

# %%
from jose import jwt, JWTError

def verify_and_decode_jwt(token: str):
    try:
        payload = jwt.decode(
            token,
            SECRET_KEY,
            algorithms=["HS256"]
        )
        return payload
    except JWTError:
        raise ValueError("Invalid or expired token")

# %%
use_context = verify_and_decode_jwt(token)

# %%
use_context
# Out:
# {'sub': 'u_test',
#  'department': 'engineering',
#  'clearance': 2,
#  'exp': 1769617175}
