# %%
# %pip install -q numpy>=1.26 pandas>=2.1 scipy>=1.11 tqdm>=4.66 python-dotenv>=1.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.1 MB/s  0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy
from tqdm.notebook import tqdm
from dotenv import load_dotenv
import os

# %%
# %pip uninstall -y numpy
# %pip install numpy<2
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Vohita\AppData\Local\Temp\pip-uninstall-_b3v4cht'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Vohita\anaconda3\envs\phase1-retrieval\Lib\site-packages\~-mpy.libs'.
# You can safely remove it manually.
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the file specified.

# %%
import numpy as np
import scipy

print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 1.26.4
# SciPy: 1.17.0

# %%
import numpy as np
import scipy

print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 1.26.4
# SciPy: 1.17.0

# %%
import os
# import json
# import numpy as np
# import pandas as pd
# from tqdm.notebook import tqdm

# %%
# import pandas as pd

# # Load pre-chunked corpus
# chunks_df = pd.read_csv("rag_corpus_chunks.csv")

# print("Total chunks:", len(chunks_df))
# # chunks_df.head()

# %%
# chunks_df.columns

# %%
# corpus = []

# for row in chunks_df.itertuples(index=False):
#     corpus.append({
#         "chunk_id": row.chunk_id,
#         "doc_id": row.doc_id,
#         "text": row.chunk_text,
#         "metadata": {
#             "source": getattr(row, "source", None)
#         }
#     })

# print("Corpus ready:", len(corpus))

# %%
# print(corpus[0])

# %%
# chunks_df.groupby("domain")["chunk_id"].count().sort_values(ascending=False)

# %%
# import pandas as pd

# data_dictionary = pd.read_csv("data_dictionary.csv")
# # data_dictionary.head(20)

# %%
# import pandas as pd

# retri = pd.read_csv("rag_retrieval_events.csv")
# retri

# %%
import pandas as pd
import numpy as np

import sys
from pathlib import Path

# Project root (current working directory)
PROJECT_ROOT = Path.cwd()
sys.path.append(str(PROJECT_ROOT))

# Pandas display settings
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Vohita\RAG\notebooks

# %%
LEGAL_DATA_PATH = "../data_legal"
GENERAL_DATA_PATH = "../data"

chunks = pd.read_csv(f"{LEGAL_DATA_PATH}/rag_corpus_chunks.csv")
docs = pd.read_csv(f"{GENERAL_DATA_PATH}/rag_corpus_documents.csv")
scenarios = pd.read_csv(f"{GENERAL_DATA_PATH}/scenarios.csv")
dictionary = pd.read_csv(f"{GENERAL_DATA_PATH}/data_dictionary.csv")
eval_runs = pd.read_csv(f"{GENERAL_DATA_PATH}/eval_runs.csv")
retrievals = pd.read_csv(f"{GENERAL_DATA_PATH}/rag_retrieval_events.csv")

# %%
from pathlib import Path

print(Path("../data_legal/rag_corpus_chunks.csv").exists())
print(Path("../data_legal/embeddings.npy").exists())
print(Path("../data_legal/faiss.index").exists())
# Out:
# True
# True
# True

# %%
tables = {
    "documents": docs,
    "chunks": chunks,
    "scenarios": scenarios,
    "dictionary": dictionary
}

for name, df in tables.items():
    print(f"{name:15s} -> rows: {df.shape[0]:6d}, cols: {df.shape[1]}")
# Out:
# documents       -> rows:    658, cols: 19
# chunks          -> rows:    458, cols: 6
# scenarios       -> rows:     62, cols: 13
# dictionary      -> rows:     99, cols: 5

# %%
# metadata docs

# %%
chunks.head()
# Out:
#   chunk_id         doc_id domain  chunk_index  estimated_tokens                                         chunk_text
# 0  LC00001  LEGAL_DOC_001  legal            0                51  Company shall not specify the business practic...
# 1  LC00002  LEGAL_DOC_001  legal            0               308  In the event that Licensor grants to another V...
# 2  LC00003  LEGAL_DOC_001  legal            0                43  During the License Term (which is identified i...
# 3  LC00004  LEGAL_DOC_001  legal            0                90  "Subject to Licensee's on\xadgoing compliance ...
# 4  LC00005  LEGAL_DOC_001  legal            0               122  During the Term, (a) Women.com will not buy, s...

# %%
docs.head
# Out:
# <bound method NDFrame.head of       doc_id               domain                                              title   source_type language  \
# 0    DOC0001          support_faq  Troubleshooting and Ticket support guide (Glob...   spreadsheet       en
# 1    DOC0002             policies  Company policy on terms and policy (Global, 2022)    pdf_manual       en
# 2    DOC0003       developer_docs  Service-to-service auth and response — enginee...  internal_doc       en
# 3    DOC0004         product_docs  Product configuration guide — Pricing and Feat...   spreadsheet       en
# 4    DOC0005      research_papers  Experimental study: Methodology in production ...   policy_file       en
# ..       ...                  ...                                                ...           ...      ...
# 653  DOC0801   data_platform_docs    Data platform architecture and governance guide  internal_doc       en
# ...

# %%
docs["domain"].value_counts()
# Out:
# domain
# support_faq            94
# financial_reports      87
# product_docs           84
# research_papers        83
# medical_guides         78
# hr_policies            78
# developer_docs         74
# policies               72
# mlops_docs              2
# data_platform_docs      2
# customer_success        2
# marketing_analytics     2
# Name: count, dtype: int64

# %%
docs["security_tier"].value_counts()
# Out:
# security_tier
# internal             230
# public               184
# restricted           175
# highly_restricted     69
# Name: count, dtype: int64

# %%
# chunks

# %%
chunks.head()
# Out:
#   chunk_id         doc_id domain  chunk_index  estimated_tokens                                         chunk_text
# 0  LC00001  LEGAL_DOC_001  legal            0                51  Company shall not specify the business practic...
# 1  LC00002  LEGAL_DOC_001  legal            0               308  In the event that Licensor grants to another V...
# 2  LC00003  LEGAL_DOC_001  legal            0                43  During the License Term (which is identified i...
# 3  LC00004  LEGAL_DOC_001  legal            0                90  "Subject to Licensee's on\xadgoing compliance ...
# 4  LC00005  LEGAL_DOC_001  legal            0               122  During the Term, (a) Women.com will not buy, s...

# %%
chunks.groupby("domain")["chunk_id"].count().sort_values(ascending=False)
# Out:
# domain
# legal    458
# Name: chunk_id, dtype: int64

# %%
# how many chunks per document?
chunks_per_doc = chunks.groupby("doc_id")["chunk_id"].count()

chunks_per_doc.describe()
# Out:
# count    46.000000
# mean      9.956522
# std       0.294884
# min       8.000000
# 25%      10.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
# Name: chunk_id, dtype: float64

# %%
# qa runs
